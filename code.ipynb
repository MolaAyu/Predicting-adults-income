# %% [markdown]
# Task 1: Working with a dataset with categorical features

# %% [markdown]
# Step 1: Reading the data

# %%
# In this step we start by reading the csv file using panda library 
import pandas as pd

# Read the CSV file.
data_training = pd.read_csv(r"C:\Users\Amerm\Desktop\Machine_learning\adult_train.csv",skiprows=0)
data_test = pd.read_csv(r"C:\Users\Amerm\Desktop\Machine_learning\adult_train.csv",skiprows=0)

Xtrain = data_training.drop('target', axis=1)
Ytrain = data_training['target']

Xtest = data_test.drop('target',axis=1)
Ytest = data_test['target']
Ytrain
Xtrain
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       27           Private  177119  Some-college             10
# 1       27           Private  216481     Bachelors             13
# 2       25           Private  256263    Assoc-acdm             12
# 3       46           Private  147640       5th-6th              3
# 4       45           Private  172822          11th              7
# 5       29           Private  203697     Bachelors             13
# 6       42         Local-gov  226020       HS-grad              9
# 7       34           Private  120461  Some-college             10
# 8       60         Local-gov  101110     Assoc-voc             11
# 9       19           Private  102723  Some-college             10
# 10      21           Private  204596    Assoc-acdm             12
# 11      31           Private  171871       Masters             14
# 12      53           Private  123011       Masters             14
# 13      35                 ?  226379       HS-grad              9
# 14      51         Local-gov  153908       Masters             14
# 15      31       Federal-gov  206823     Bachelors             13
# 16      37           Private  164898  Some-college             10
# 17      29           Private   87507     Doctorate             16
# 18      68                 ?  117542       HS-grad              9
# 19      24           Private  176389       HS-grad              9
# 20      46           Private  268358          11th              7
# 21      53           Private  126592  Some-college             10
# 22      54           Private  421561  Some-college             10
# 23      21           Private  322931  Some-college             10
# 24      56           Private  245215     Doctorate             16
# 25      35  Self-emp-not-inc   97277   Prof-school             15
# 26      46           Private  219611  Some-college             10
# 27      36  Self-emp-not-inc   36425  Some-college             10
# 28      20           Private  170800  Some-college             10
# 29      29           Private  193152       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32531   41           Private  152292     Bachelors             13
# 32532   19           Private  220101  Some-college             10
# 32533   27  Self-emp-not-inc  140863           9th              5
# 32534   44  Self-emp-not-inc  127482       HS-grad              9
# 32535   64           Private  148606          10th              6
# 32536   21           Private  163870          10th              6
# 32537   20           Private  278391  Some-college             10
# 32538   48  Self-emp-not-inc  328606   Prof-school             15
# 32539   24           Private   36058     Bachelors             13
# 32540   47      Self-emp-inc  102308   Prof-school             15
# 32541   21           Private  155818       HS-grad              9
# 32542   37  Self-emp-not-inc  112497       Masters             14
# 32543   45           Private  167523       HS-grad              9
# 32544   34  Self-emp-not-inc   24961       HS-grad              9
# 32545   60         State-gov  234854     Doctorate             16
# 32546   24           Private  211968  Some-college             10
# 32547   23         State-gov   61743       5th-6th              3
# 32548   30           Private   36340       HS-grad              9
# 32549   17           Private  153035          10th              6
# 32550   17                 ?  151141          10th              6
# 32551   26           Private  159732       HS-grad              9
# 32552   28         Local-gov  175262    Assoc-acdm             12
# 32553   34                 ?  330301       7th-8th              4
# 32554   56           Private   91905       HS-grad              9
# 32555   65                 ?  404601       HS-grad              9
# 32556   43         Local-gov   33331       Masters             14
# 32557   44           Private   98466          10th              6
# 32558   23           Private   45317  Some-college             10
# 32559   45         Local-gov  215862     Doctorate             16
# 32560   25           Private  186925  Some-college             10
#
#            marital-status         occupation    relationship  \
# 0                Divorced       Adm-clerical       Unmarried
# 1           Never-married     Prof-specialty   Not-in-family
# 2      Married-civ-spouse              Sales         Husband
# 3      Married-civ-spouse   Transport-moving         Husband
# 4                Divorced   Transport-moving   Not-in-family
# 5      Married-civ-spouse     Prof-specialty       Own-child
# 6               Separated      Other-service   Not-in-family
# 7                Divorced       Adm-clerical   Not-in-family
# 8                Divorced     Prof-specialty       Unmarried
# 9           Never-married       Adm-clerical       Own-child
# 10          Never-married       Adm-clerical       Own-child
# 11          Never-married     Prof-specialty   Not-in-family
# 12     Married-civ-spouse    Exec-managerial         Husband
# 13     Married-civ-spouse                  ?  Other-relative
# 14               Divorced    Exec-managerial   Not-in-family
# 15               Divorced    Protective-serv   Not-in-family
# 16     Married-civ-spouse       Craft-repair         Husband
# 17     Married-civ-spouse     Prof-specialty         Husband
# 18     Married-civ-spouse                  ?         Husband
# 19     Married-civ-spouse       Craft-repair         Husband
# 20              Separated  Machine-op-inspct   Not-in-family
# 21     Married-civ-spouse       Craft-repair         Husband
# 22     Married-civ-spouse     Prof-specialty         Husband
# 23          Never-married       Craft-repair   Not-in-family
# 24     Married-civ-spouse     Prof-specialty         Husband
# 25     Married-civ-spouse     Prof-specialty         Husband
# 26     Married-civ-spouse       Adm-clerical         Husband
# 27               Divorced              Sales       Unmarried
# 28          Never-married    Farming-fishing       Own-child
# 29          Never-married  Handlers-cleaners   Not-in-family
# ...                   ...                ...             ...
# 32531  Married-civ-spouse     Prof-specialty         Husband
# 32532       Never-married       Adm-clerical   Not-in-family
# 32533  Married-civ-spouse       Craft-repair         Husband
# 32534  Married-civ-spouse       Craft-repair         Husband
# 32535           Separated      Other-service   Not-in-family
# 32536  Married-civ-spouse      Other-service         Husband
# 32537       Never-married       Adm-clerical       Own-child
# 32538            Divorced     Prof-specialty       Unmarried
# 32539       Never-married              Sales   Not-in-family
# 32540  Married-civ-spouse     Prof-specialty         Husband
# 32541       Never-married      Other-service       Own-child
# 32542  Married-civ-spouse    Exec-managerial         Husband
# 32543  Married-civ-spouse   Transport-moving         Husband
# 32544  Married-civ-spouse    Farming-fishing         Husband
# 32545  Married-civ-spouse     Prof-specialty         Husband
# 32546       Never-married              Sales   Not-in-family
# 32547       Never-married   Transport-moving   Not-in-family
# 32548       Never-married       Adm-clerical       Unmarried
# 32549       Never-married              Sales       Own-child
# 32550       Never-married                  ?       Own-child
# 32551             Widowed   Transport-moving   Not-in-family
# 32552  Married-civ-spouse    Protective-serv         Husband
# 32553           Separated                  ?       Unmarried
# 32554  Married-civ-spouse              Sales            Wife
# 32555  Married-civ-spouse                  ?         Husband
# 32556  Married-civ-spouse    Exec-managerial         Husband
# 32557       Never-married    Farming-fishing       Unmarried
# 32558           Separated              Sales       Own-child
# 32559  Married-civ-spouse    Exec-managerial         Husband
# 32560       Never-married      Other-service   Not-in-family
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White  Female             0             0              44
# 1                   White  Female             0             0              40
# 2                   White    Male             0             0              40
# 3      Amer-Indian-Eskimo    Male             0          1902              40
# 4                   White    Male             0          2824              76
# 5                   White    Male             0             0              75
# 6                   Black  Female             0             0              60
# 7                   White  Female             0             0              50
# 8                   White    Male             0             0              40
# 9                   White  Female             0             0              40
# 10                  White  Female             0             0               8
# 11                  White  Female             0             0              46
# 12                  White    Male             0             0              45
# 13                  White  Female             0             0              25
# 14                  White  Female             0             0              40
# 15                  White    Male             0             0              50
# 16                  White    Male             0             0              52
# 17     Asian-Pac-Islander    Male             0             0              60
# 18                  White    Male          1409             0              15
# 19                  White    Male             0             0              40
# 20                  White  Female             0             0              40
# 21                  Black    Male          7688             0              40
# 22                  White    Male             0             0              40
# 23                  White    Male             0             0              55
# 24                  White    Male             0             0              50
# 25                  White    Male             0             0              65
# 26                  White    Male             0             0              40
# 27                  White  Female             0             0              35
# 28                  White  Female             0             0              40
# 29                  White    Male             0          1408              40
# ...                   ...     ...           ...           ...             ...
# 32531               White    Male             0             0              50
# 32532               White  Female             0             0              40
# 32533               White    Male             0             0              40
# 32534               White    Male          7298             0              50
# 32535               White  Female             0             0              35
# 32536               White    Male          3908             0              40
# 32537               White    Male             0             0              25
# 32538               White    Male         14084             0              63
# 32539               White    Male             0             0              50
# 32540               White    Male             0          2415              45
# 32541               White  Female             0             0              20
# 32542               White    Male             0             0              50
# 32543               White    Male             0          2179              45
# 32544               White    Male             0             0              80
# 32545               White    Male             0          1902              40
# 32546               White  Female             0             0              24
# 32547               White    Male             0             0              35
# 32548               White  Female             0             0              24
# 32549               White  Female             0             0              20
# 32550               White    Male             0             0              30
# 32551               White    Male             0             0              40
# 32552               White    Male             0          2002              40
# 32553               Black  Female             0             0              40
# 32554               White  Female             0             0               4
# 32555               White    Male          2414             0              30
# 32556               White    Male             0             0              40
# 32557               White    Male             0             0              35
# 32558               White  Female             0             0              40
# 32559               White    Male          7688             0              45
# 32560               White    Male          2597             0              48
#
#       native-country
# 0      United-States
# 1      United-States
# 2      United-States
# 3      United-States
# 4      United-States
# 5      United-States
# 6                  ?
# 7      United-States
# 8      United-States
# 9      United-States
# 10     United-States
# 11     United-States
# 12     United-States
# 13     United-States
# 14     United-States
# 15     United-States
# 16     United-States
# 17             India
# 18     United-States
# 19     United-States
# 20     United-States
# 21     United-States
# 22     United-States
# 23     United-States
# 24     United-States
# 25     United-States
# 26     United-States
# 27     United-States
# 28     United-States
# 29     United-States
# ...              ...
# 32531  United-States
# 32532  United-States
# 32533  United-States
# 32534        England
# 32535  United-States
# 32536  United-States
# 32537      Nicaragua
# 32538  United-States
# 32539  United-States
# 32540  United-States
# 32541  United-States
# 32542  United-States
# 32543  United-States
# 32544  United-States
# 32545  United-States
# 32546  United-States
# 32547  United-States
# 32548  United-States
# 32549  United-States
# 32550  United-States
# 32551  United-States
# 32552        England
# 32553  United-States
# 32554  United-States
# 32555  United-States
# 32556  United-States
# 32557  United-States
# 32558  United-States
# 32559  United-States
# 32560  United-States
#
# [32561 rows x 14 columns]

# %% [markdown]
# Step 1 objective is to read the data from the training and testing files. Unlike the previous assignemnt here we didnt split the data to training and testing because its already splitted in two files.

# %% [markdown]
# step 2:  Encoding the features as numbers.

# %%
dicts_for_my_training_data = Xtrain.to_dict('records')

# %%
dicts_for_my_test_data = Xtest.to_dict('records')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Ytrain)
Ytrain=le.transform(Ytrain)

# %% [markdown]
# In manner to transform the data to numerical data we need to create dictionary vectors for the training and the test data. By using Pandas which includes a utility to convert a DataFrame into a list of dictionaries.

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer()
X_train_encoded = dv.fit_transform(dicts_for_my_training_data)
X_train_encoded
# Out:
# <32561x108 sparse matrix of type '<class 'numpy.float64'>'
# 	with 394963 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The next step was to create the DictVectorizer and then fit the lables.

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Ytrain)
Ytrain=le.transform(Ytrain)
Ytrain
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
clf1 = DecisionTreeClassifier()
cross_val_score(clf1, X_train_encoded, Ytrain).mean()
# Out:
# C:\Users\Amerm\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.8117378872626254

# %% [markdown]
# After that we have used the DecisionTreeClassifier and used the accuracy measure cross validation score to test the accuracy
# of the data

# %% [markdown]
# Label Encoder

# %%
X_test_encoded = dv.transform(dicts_for_my_test_data)
X_test_encoded
# Out:
# <32561x108 sparse matrix of type '<class 'numpy.float64'>'
# 	with 455854 stored elements in Compressed Sparse Row format>

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Ytest)
Ytest=le.transform(Ytest)

# %% [markdown]
# Then we fitted the test data befoer using the pipline to combine all the previous steps

# %% [markdown]
# Step 3. Combining the steps.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
pipeline = make_pipeline(DictVectorizer(),DecisionTreeClassifier())
pipeline.fit(dicts_for_my_training_data, Ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('dictvectorizer',
#                  DictVectorizer(dtype=<class 'numpy.float64'>, separator='=',
#                                 sort=True, sparse=True)),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(class_weight=None, criterion='gini',
#                                         max_depth=None, max_features=None,
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort=False, random_state=None,
#                                         splitter='best'))],
#          verbose=False)

# %% [markdown]
# To predict on new data it is as simple as calling the predict method and the preprocessing steps will be applied followed by the prediction.

# %%
Y_new = pipeline.predict(dicts_for_my_test_data)

# %%
# Cross-validation performance of test set with the predicted label
cross_val_score(clf1, X_test_encoded, Y_new).mean()
# Out:
# C:\Users\Amerm\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.813212121639108

# %%
# Cross-validation performance of test data usinf decision tree classifier
cross_val_score(clf1, X_test_encoded, Ytest).mean()
# Out:
# C:\Users\Amerm\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.8123520690222028

# %% [markdown]
# Task 2: Decision trees and random forests

# %% [markdown]
#  Underfitting and overfitting in decision tree classifiers.

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Ytrain)
Ytrain=le.transform(Ytrain)
Ytrain
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Ytest)
Ytest=le.transform(Ytest)
Ytest
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
clf2= DecisionTreeClassifier()
clf2.fit(X_train_encoded, Ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn import tree
import pydotplus
dot_data=StringIO()
tree.export_graphviz(clf2,out_file=dot_data,filled=True,rounded=False,impurity=False)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png)

predict1=clf2.predict(X_train_encoded)
print(predict1)
predict2=clf2.predict(X_test_encoded)
print(predict2)

from sklearn.metrics import confusion_matrix
c1=confusion_matrix(Ytrain,predict1)
c1

total=sum(sum(c1))
#accuracy=(c1[0,0]+c1[1,1])/total
a1=c1[0,0]
a2=c1[1,1]
accuracy=(a1+a2)/total
print('Accuracy of training data:',accuracy)

c2=confusion_matrix(Ytest,predict2)
c2
total1=sum(sum(c2))
a3=c2[0,0]
a4=c2[1,1]
accuracy1=(a3+a4)/total1
print('Accuracy of test data:',accuracy1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-53-23b80ac2f2db> in <module>
#       2 from sklearn.externals.six import StringIO
#       3 from sklearn import tree
# ----> 4 import pydotplus
#       5 dot_data=StringIO()
#       6 tree.export_graphviz(clf2,out_file=dot_data,filled=True,rounded=False,impurity=False)
#
# ModuleNotFoundError: No module named 'pydotplus'

# %% [markdown]
# The accuracy of trianing set is almost 100%. and using the same model the test data accuracy is 81%. The model is good in trainning data and it is also good in test data.No problem with overfitting. Since we have nice predition on the future data set.

# %%
from sklearn.ensemble import RandomForestClassifier
clf3= RandomForestClassifier()
clf3.fit(X_train_encoded, Ytrain)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn import tree
import pydotplus
dot_data=StringIO()
tree.export_graphviz(clf2,out_file=dot_data,filled=True,rounded=False,impurity=False)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png)

predict1=clf3.predict(X_train_encoded)
print(predict1)
predict2=clf3.predict(X_test_encoded)
print(predict2)

from sklearn.metrics import confusion_matrix
c1=confusion_matrix(Ytrain,predict1)
c1

total=sum(sum(c1))
#accuracy=(c1[0,0]+c1[1,1])/total
a1=c1[0,0]
a2=c1[1,1]
accuracy=(a1+a2)/total
print('Accuracy of training data:',accuracy)

c2=confusion_matrix(Ytest,predict2)
c2
total1=sum(sum(c2))
a3=c2[0,0]
a4=c2[1,1]
accuracy1=(a3+a4)/total1
print('Accuracy of test data:',accuracy1)

# %% [markdown]
# Using the defualt hyperparameter n_estimators parameter the accuracy of test data increases.

# %% [markdown]
# Let us try using different n_estimators values

# %%
from sklearn.ensemble import RandomForestClassifier
clf4= RandomForestClassifier(n_estimators=100,n_jobs = -1)
clf4.fit(X_train_encoded, Ytrain)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn import tree
import pydotplus
dot_data=StringIO()
tree.export_graphviz(clf2,out_file=dot_data,filled=True,rounded=False,impurity=False)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png)

predict1=clf4.predict(X_train_encoded)
print(predict1)
predict2=clf4.predict(X_test_encoded)
print(predict2)

from sklearn.metrics import confusion_matrix
c1=confusion_matrix(Ytrain,predict1)
c1

total=sum(sum(c1))
#accuracy=(c1[0,0]+c1[1,1])/total
a1=c1[0,0]
a2=c1[1,1]
accuracy=(a1+a2)/total
print('Accuracy of training data:',accuracy)

c2=confusion_matrix(Ytest,predict2)
c2
total1=sum(sum(c2))
a3=c2[0,0]
a4=c2[1,1]
accuracy1=(a3+a4)/total1
print('Accuracy of test data:',accuracy1)

# %% [markdown]
# What's the difference between the curve for a decision tree and for a random forest with an ensemble size of 1, and why do we see this difference?
# Random forest is more use full in feature predition than decision tree.
# What happens with the curve for random forests as the ensemble size grows?
# The accuracy of both the trian set and test set increases accordingly.
# What happens with the best observed test set accuracy as the ensemble size grows?
# We tried with two sample so, but we observed that when the the ensemble size increases the accuracy of both the trianing and test set increases.
# What happens with the training time as the ensemble size grows?
# Its accuracy approaches to 1. Therefore the model is good for both data sets.

# %% [markdown]
# Task 3: Feature importances in random forest classifiers

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
rf = RandomForestClassifier(n_estimators = 100,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)
rf.fit(X_train_encoded, Ytrain)
print('R^2 Training Score: {:.2f} \nOOB Score: {:.2f} \nR^2 Validation Score: {:.2f}'.format(rf.score(X_train_encoded, Ytrain), 
                                                                                            rf.oob_score_,
                                                                                          rf.score(X_test_encoded, Ytest)))

print("Accuracy:",metrics.accuracy_score(Y_new, Ytest))

#import pandas as pd
#clf1.fit(Xtrain,Ytrain)
#feature_imp = pd.Series(clf1.feature_importances_,index=data_training.feature_names).sort_values(ascending=False)
#feature_imp
# Out:
# R^2 Training Score: 1.00
# OOB Score: 0.85
# R^2 Validation Score: 1.00
# Accuracy: 0.9999692884125181

# %% [markdown]
# In this taks we calculated the importance scores for individual features and acucracy metric score for the predicted data and the test data from the previous steps
